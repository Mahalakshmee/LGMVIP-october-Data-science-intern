# %% [markdown]
# **Task-2(IMAGE TO PENCIL SKETCH WITH PYTHON)**
#
# Name:MAHALAKSHMEE B
#
# LEVEL:BEGGINER
#
# LANGUAGE:PYTHON

# %%
import cv2

# %%
from google.colab.patches import cv2_imshow

# %%
a = cv2.imread("/content/sample_data/nature.jpg")

# %%
cv2_imshow(a)
# Out:
# <PIL.Image.Image image mode=RGB size=508x339 at 0x7F5969B94990>

# %%
#converting original image(BGR scale) to gray scale
gray = cv2.cvtColor(a,cv2.COLOR_BGR2GRAY)

# %%
cv2_imshow(gray)
# Out:
# <PIL.Image.Image image mode=L size=508x339 at 0x7F596826C210>

# %%
#inverting the grey image
invert = cv2.bitwise_not(gray)

# %%
cv2_imshow(invert)
# Out:
# <PIL.Image.Image image mode=L size=508x339 at 0x7F5968271250>

# %%
#getting the blurred inverted image
blur = cv2.GaussianBlur(invert,(21,21),0)

cv2_imshow(blur)
# Out:
# <PIL.Image.Image image mode=L size=508x339 at 0x7F59639F6690>

# %%
def sketch(i,j):
  return cv2.divide(i,255-j,scale=256)

final = sketch(gray,blur)
cv2_imshow(final)
# Out:
# <PIL.Image.Image image mode=L size=508x339 at 0x7F5968271D10>
